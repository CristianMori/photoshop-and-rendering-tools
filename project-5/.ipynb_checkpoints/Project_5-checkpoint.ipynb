# %% [markdown]
# # Programming Project #5: Video Stitching and Processing

# %% [markdown]
# ## CS445: Computational Photography - Fall 2019

# %% [markdown]
# ### Part I: Stitch two key frames <img src="images/project_5/image005.jpg" alt="Drawing" style="float: right; width: 450px"/>
#
# #### This involves:
# 1. compute homography H between two frames;
# 2. project each frame onto the same surface;
# 3. blend the surfaces.
#
#
#
# Check that your homography is correct by plotting four points that form a square in frame 270 and their projections in each image, like this:
# <p>
#     <img src="images/project_5/image002.jpg" alt="Drawing"/>
#     <img src="images/project_5/image004.jpg" alt="Drawing"/>
# </p>

# %%
import cv2
import numpy as np
from numpy.linalg import svd, inv

# %matplotlib inline
from matplotlib import pyplot as plt

# %%
# images location
im1 = './images/input/frames/f0450.jpg'
im2 = './images/input/frames/f0270.jpg'

# Load an color image in grayscale
im1 = cv2.imread(im1)
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)

im2 = cv2.imread(im2)
im2 = cv2.cvtColor(im2, cv2.COLOR_BGR2RGB)

# %%
def auto_homography(Ia,Ib, homography_func=None):
    '''
    Computes a homography that maps points from Ia to Ib

    Input: Ia and Ib are images
    Output: H is the homography

    '''
    if Ia.dtype == 'float32' and Ib.dtype == 'float32':
        Ia = (Ia*255).astype(np.uint8)
        Ib = (Ib*255).astype(np.uint8)
    
    Ia_gray = cv2.cvtColor(Ia,cv2.COLOR_BGR2GRAY)
    Ib_gray = cv2.cvtColor(Ib,cv2.COLOR_BGR2GRAY)

    # Initiate SIFT detector
    sift = cv2.xfeatures2d.SIFT_create()
    
    # find the keypoints and descriptors with SIFT
    kp_a, des_a = sift.detectAndCompute(Ia_gray,None)
    kp_b, des_b = sift.detectAndCompute(Ib_gray,None)    
    
    # BFMatcher with default params
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des_a,des_b, k=2)

    # Apply ratio test
    good = []
    for m,n in matches:
        if m.distance < 0.75*n.distance:
            good.append(m)
   
    numMatches = int(len(good))

    matches = good

    # Xa and Xb are 3xN matrices that contain homogeneous coordinates for the N
    # matching points for each image
    Xa = np.ones((3,numMatches))
    Xb = np.ones((3,numMatches))
    
    for idx, match_i in enumerate(matches):
        Xa[:,idx][0:2] = kp_a[match_i.queryIdx].pt
        Xb[:,idx][0:2] = kp_b[match_i.trainIdx].pt

    ## RANSAC
    niter = 1000
    best_score = 0

    for t in range(niter):
        # estimate homography
        subset = np.random.choice(numMatches, 4, replace=False)
        pts1 = Xa[:,subset]
        pts2 = Xb[:,subset]
        
        H_t = homography_func(pts1, pts2) # edit helper code below (computeHomography)

        # score homography
        Xb_ = np.dot(H_t, Xa) # project points from first image to second using H
        du = Xb_[0,:]/Xb_[2,:] - Xb[0,:]/Xb[2,:]
        dv = Xb_[1,:]/Xb_[2,:] - Xb[1,:]/Xb[2,:]

        ok_t = np.sqrt(du**2 + dv**2) < 5  # you may need to play with this threshold
        score_t = sum(ok_t)

        if score_t > best_score:
            best_score = score_t
            H = H_t
            in_idx = ok_t
    
    print('best score: {:02f}'.format(best_score))

    # Optionally, you may want to re-estimate H based on inliers

    return H

# %%
def computeHomography(pts1, pts2):
    '''
    Compute homography that maps from pts1 to pts2 using least squares solver
     
    Input: pts1 and pts2 are 3xN matrices for N points in homogeneous
    coordinates. 
    
    Output: H is a 3x3 matrix, such that pts2~=H*pts1
    '''
    N = pts1.shape[1]
    A = np.zeros((2*N,9))
    
    for i in range(N):
        x = pts1[:, i]
        x_p = pts2[:, i]
        u,v = x[0], x[1]
        u_p,v_p = x_p[0], x_p[1]
        A[2*i,:] = np.array([-u, -v, -1, 0, 0, 0, u*u_p, v*u_p, u_p])
        A[2*i+1, :] = np.array([0, 0, 0, -u, -v, -1, u*v_p, v*v_p, v_p])
    
    _,_,V = np.linalg.svd(A)
    h = V[V.shape[0]-1,:]
    H_n = np.reshape(h, (3,3))
    return H_n

# %%
H = auto_homography(im2,im1, computeHomography)
# Out:
# best score: 160.000000

# %%
ht, wd, num_channels = 450,800,3
corners, H_t, out = np.zeros((3,4)), np.identity(3), np.zeros((450,800,3))
corners_t = H@(np.array([[0, 0, 1], [360, 0, 1], [0, 480, 1], [360, 480, 1]])).T
corners[0],corners[1] = corners_t[0]/corners_t[2], corners_t[1]/corners_t[2]
H_t[0][2],H_t[1][2] = -1*min(corners[0]), -1*min(corners[1])
img_warped1, img_warped2= cv2.warpPerspective(im1, H_t, (800, 450)), cv2.warpPerspective(im2, H_t.dot(H), (800, 450))

zero_row, zero_col = np.where(np.any(img_warped2 == [0,0,0], axis=-1))
non_row, non_col = np.where(np.any(img_warped2 != [0,0,0], axis=-1))
out[zero_row,zero_col] = img_warped1[zero_row,zero_col]
out[non_row,non_col] = img_warped2[non_row,non_col]
# Out:
# [[ 4.86010859e-03  2.17090802e-04 -9.97124813e-01]
#  [ 6.10778789e-05  4.59256343e-03 -7.53803073e-02]
#  [ 1.97080289e-06  1.67658560e-07  3.89274039e-03]]

# %%
plt.figure(figsize=(60,10))
plt.imshow(out)

# %% [markdown]
# ### Part II: Panorama using five key frames
#
# In this part you will produce a panorama using five key frames. Let's determine frames [90, 270, 450, 630, 810] as key frames. The goal is to map all the five frames onto the plane corresponding to frame 450 (that we also call the _reference frame_). For the frames 270 and 630 you can follow the instructions in part 1.
#
# <img src="images/project_5/header.jpg" alt="Drawing" style="float: center; width: 500px"/>
#
# Mapping frame 90 to frame 450 is difficult because they share very little area. Therefore you need to perform a two stage mapping by using frame 270 as a guide. Compute one projection from 90 to 270 and one from 270 to 450 and multiply the two matrices. This produces a projection from 90 to 450 even though these frames have very little area in common

# %%
import cv2
import numpy as np

# %%
master_frames =[90, 270, 450, 630, 810]
reference_frame = 450
reference_idx = master_frames.index(reference_frame)

# images location
im1 = './images/input/frames/f0090.jpg'
im2 = './images/input/frames/f0270.jpg'
im3 = './images/input/frames/f0450.jpg'
im4 = './images/input/frames/f0630.jpg'
im5 = './images/input/frames/f0810.jpg'

# Load an color image in grayscale
im1 = cv2.imread(im1)
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)

im2 = cv2.imread(im2)
im2 = cv2.cvtColor(im2, cv2.COLOR_BGR2RGB)

im3 = cv2.imread(im3)
im3 = cv2.cvtColor(im3, cv2.COLOR_BGR2RGB)

im4 = cv2.imread(im4)
im4 = cv2.cvtColor(im4, cv2.COLOR_BGR2RGB)

im5 = cv2.imread(im5)
im5 = cv2.cvtColor(im5, cv2.COLOR_BGR2RGB)

# %%
def createOutput2(frame450, h270, frame270, h90, frame90, h630, frame630, h810, frame810):
    h1, w1, _ = im1.shape
    
    corners = np.array([[0, 0, 1], [360, 0, 1], [0, 480, 1], [360, 480, 1]])
    corners_t = h90@corners.T
    holder = np.zeros((3,4))
    holder[0] = corners_t[0]/corners_t[2]
    holder[1] = corners_t[1]/corners_t[2]
    H_t = computeTranslation(holder)
    
    img_warped2 = cv2.warpPerspective(frame90, H_t.dot(h90), (1600, 600))
    img_warped3 = cv2.warpPerspective(frame270, H_t.dot(h270), (1600, 600))
    img_warped4 = cv2.warpPerspective(frame630, H_t.dot(h630), (1600, 600))
    img_warped5 = cv2.warpPerspective(frame810, H_t.dot(h810), (1600, 600))
    
    img_warped = cv2.warpPerspective(frame450, H_t, (1600,600))
    out = np.zeros((600,1600,3))
    h, w, _ = img_warped.shape
    for r in range(h):
        for c in range(w):
            out[r][c] = img_warped2[r][c]
    for r in range(h):
        for c in range(w):
            if out[r][c][0] == 0 and out[r][c][1] == 0 and out[r][c][2] == 0:
                out[r][c] = img_warped3[r][c]
    for r in range(h):
        for c in range(w):
            if out[r][c][0] == 0 and out[r][c][1] == 0 and out[r][c][2] == 0:
                out[r][c] = img_warped[r][c]
    for r in range(h):
        for c in range(w):
            if out[r][c][0] == 0 and out[r][c][1] == 0 and out[r][c][2] == 0:
                out[r][c] = img_warped4[r][c]
    for r in range(h):
        for c in range(w):
            if out[r][c][0] == 0 and out[r][c][1] == 0 and out[r][c][2] == 0:
                out[r][c] = img_warped5[r][c]
    return out/255

# %%
H_1 = auto_homography(im2,im3, computeHomography)

H_2 = auto_homography(im1,im2, computeHomography)
left = np.matmul(H_1, H_2)

H_3 = auto_homography(im4,im3, computeHomography)
H_4 = auto_homography(im5,im4, computeHomography)
right = np.matmul(H_3, H_4)

out = createOutput2(im3, H_1, im2, left, im1, H_3, im4, right, im5)
plt.figure(figsize=(60,10))
plt.imshow(out)
# Out:
# best score: 159.000000
# best score: 202.000000
# best score: 131.000000
# best score: 97.000000

# %% [markdown]
# ### Part 3: Map the video to the reference plane

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from math import floor

import utils

# %%
dir_frames = 'images/input/frames'
filenames = []
filesinfo = os.scandir(dir_frames)

# %%
filenames = [f.path for f in filesinfo if f.name.endswith(".jpg")]
filenames.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))

# %%
frameCount = len(filenames)
frameHeight, frameWidth, frameChannels = cv2.imread(filenames[0]).shape
frames = np.zeros((frameCount, frameHeight, frameWidth, frameChannels),dtype=np.float32)

# %%
for idx, file_i in enumerate(filenames):
    frames[idx] = cv2.cvtColor(cv2.imread(file_i), cv2.COLOR_BGR2RGB) / 255.0
cv2.imwrite('test.jpg', frames[6])
# Out:
# True

# %%
## Example usage of utils.projectImage

pastHomographies = np.zeros((len(filenames),len(filenames), 3, 3),dtype=np.float32)
originTranslations = np.zeros((len(filenames), 2), dtype=np.float32)
sourceFrameIndex = 630
referenceFrameIndex = 450

# %%
projected = np.zeros((900, 512, 1632, 3), dtype=np.float64)
for i in range(0,450):
    projectedSource, _, originTranslations = utils.projectImage(frames, i, referenceFrameIndex,
                                                            pastHomographies, originTranslations,
                                                            auto_H_func=auto_homography, homography_func=computeHomography, normalization_func=None)
    cv2.imwrite('aligned_frames/a{:04d}.jpg'.format(i), cv2.cvtColor(projectedSource, cv2.COLOR_RGB2BGR))
    projected[i] = projectedSource
    
    
    projectedSource, _, originTranslations = utils.projectImage(frames, 899-i, referenceFrameIndex,
                                                            pastHomographies, originTranslations,
                                                            auto_H_func=auto_homography, homography_func=computeHomography, normalization_func=None)
    cv2.imwrite('aligned_frames/a{:04d}.jpg'.format(899-i), cv2.cvtColor(projectedSource, cv2.COLOR_RGB2BGR))
    projected[899-i] = projectedSource
# Out:
# best score: 2630.000000
# best score: 29.000000
# Overlap:24838
# Error:0.0007349351940270817
# Finding better homography...
# best score: 65.000000
# Overlap:40514
# Error:0.0005169395142069769
# best score: 2751.000000
# best score: 261.000000
# Overlap:148246
# Error:0.00018387441030591066
# Found better homography
# best score: 32.000000
# Overlap:32885
# Error:0.0006285090204299022
# Finding better homography...
# best score: 53.000000
# Overlap:58331
# Error:0.0004423224492551636
# best score: 3035.000000
# best score: 134.000000
# Overlap:137465
# Error:0.00030209901590170146
# Found better homography
# best score: 26.000000
# Overlap:24831
# Error:0.000728543845372918
# Finding better homography...
# best score: 61.000000
# Overlap:40554
# Error:0.0005142824211242207
# best score: 2755.000000
# best score: 273.000000
# Overlap:148582
# Error:0.00018701093539594805
# Found better homography
# best score: 22.000000
# Overlap:32858
# Error:0.0006142895429303209
# Finding better homography...
# best score: 56.000000
# Overlap:57788
# Error:0.00045197047588114254
# best score: 3116.000000
# best score: 118.000000
# Overlap:138771
# Error:0.0002989709325656683
# Found better homography
# best score: 32.000000
# Overlap:24639
# Error:0.000723378885994048
# Finding better homography...
# Overlap:40554
# Error:0.0005142838828251271
# best score: 273.000000
# Overlap:148798
# Error:0.00018345209404101116
# Found better homography
# best score: 26.000000
# Overlap:32990
# Error:0.000607879705730077
# Finding better homography...
# Overlap:57788
# Error:0.0004519706490747416
# best score: 122.000000
# Overlap:137957
# Error:0.0003045965239078099
# Found better homography
# best score: 36.000000
# Overlap:24973
# Error:0.0006976495101248655
# Finding better homography...
# best score: 69.000000
# Overlap:41501
# Error:0.0005194760292905256
# best score: 2682.000000
# best score: 277.000000
# Overlap:148529
# Error:0.00018311765110984153
# Found better homography
# best score: 33.000000
# Overlap:33546
# Error:0.0006150696323155828
# Finding better homography...
# best score: 47.000000
# Overlap:57023
# Error:0.0004557895267964411
# best score: 3130.000000
# best score: 159.000000
# Overlap:139878
# Error:0.00029889274519523385
# Found better homography
# best score: 40.000000
# Overlap:25972
# Error:0.0007164757177011064
# Finding better homography...
# best score: 68.000000
# Overlap:41182
# Error:0.0005250478282360016
# best score: 2786.000000
# best score: 335.000000
# Overlap:149189
# Error:0.00018409602203042723
# Found better homography
# best score: 31.000000
# Overlap:34517
# Error:0.0005785865539789587
# Finding better homography...
# best score: 58.000000
# Overlap:56872
# Error:0.00045451281754113973
# best score: 3126.000000
# best score: 153.000000
# Overlap:140297
# Error:0.0002963175594223413
# Found better homography
# best score: 30.000000
# Overlap:26497
# Error:0.0007360331293501343
# Finding better homography...
# best score: 60.000000
# Overlap:42095
# Error:0.0005244678912850074
# best score: 2663.000000
# best score: 289.000000
# Overlap:148920
# Error:0.0001816125245857611
# Found better homography
# best score: 32.000000
# Overlap:34860
# Error:0.0006053377153093026
# Finding better homography...
# best score: 70.000000
# Overlap:56991
# Error:0.00044861742663186347
# best score: 3158.000000
# best score: 146.000000
# Overlap:140673
# Error:0.00029949260802451377
# Found better homography
# best score: 35.000000
# Overlap:25833
# Error:0.0006982260339825162
# Finding better homography...
# Overlap:42095
# Error:0.0005244680110876946
# best score: 309.000000
# Overlap:149606
# Error:0.00018212481620597394
# Found better homography
# best score: 27.000000
# Overlap:33740
# Error:0.0005922537175990231
# Finding better homography...
# Overlap:56991
# Error:0.0004486161983060997
# best score: 147.000000
# Overlap:141553
# Error:0.0002967872925698155
# Found better homography
# best score: 43.000000
# Overlap:26376
# Error:0.0007273709469623333
# Finding better homography...
# best score: 74.000000
# Overlap:42274
# Error:0.00051179862019231
# best score: 2672.000000
# best score: 276.000000
# Overlap:149384
# Error:0.00018042727435813686
# Found better homography
# best score: 31.000000
# Overlap:36318
# Error:0.0005688316846454313
# Finding better homography...
# best score: 54.000000
# Overlap:56721
# Error:0.0004347671430522554
# best score: 3201.000000
# best score: 151.000000
# Overlap:143843
# Error:0.00029332758463699053
# Found better homography
# best score: 41.000000
# Overlap:25550
# Error:0.0006937064873515596
# Finding better homography...
# best score: 66.000000
# Overlap:42570
# Error:0.0005195137079800767
# best score: 2705.000000
# best score: 288.000000
# Overlap:150394
# Error:0.00017946370514515086
# Found better homography
# best score: 21.000000
# Overlap:36971
# Error:0.0005448977991270201
# Finding better homography...
# best score: 58.000000
# Overlap:55401
# Error:0.00045363466074514064
# best score: 3273.000000
# best score: 175.000000
# Overlap:145615
# Error:0.0002946640274524136
# Found better homography
# best score: 37.000000
# Overlap:25599
# Error:0.0007139670959567137
# Finding better homography...
# best score: 60.000000
# Overlap:42943
# Error:0.0005135275855410421
# best score: 2614.000000
# best score: 269.000000
# Overlap:149556
# Error:0.00017873038676257774
# Found better homography
# best score: 21.000000
# Overlap:37697
# Error:0.0005487297914413667
# Finding better homography...
# best score: 59.000000
# Overlap:55171
# Error:0.00046376934235779906
# best score: 3148.000000
# best score: 122.000000
# Overlap:145736
# Error:0.00029830235180532306
# Found better homography
# best score: 29.000000
# Overlap:24608
# Error:0.0007243730530464506
# Finding better homography...
# Overlap:42943
# Error:0.0005135284659302903
# best score: 283.000000
# Overlap:148518
# Error:0.0001807520100476375
# Found better homography
# best score: 30.000000
# Overlap:37656
# Error:0.0005580453119204326
# Finding better homography...
# Overlap:55171
# Error:0.000463768978823925
# best score: 155.000000
# Overlap:145996
# Error:0.0002965782963579016
# Found better homography
# best score: 43.000000
# Overlap:25726
# Error:0.0007066966178114042
# Finding better homography...
# best score: 65.000000
# Overlap:43592
# Error:0.0005194855227484663
# best score: 2584.000000
# best score: 326.000000
# Overlap:146547
# Error:0.0001818610710279236
# Found better homography
# best score: 22.000000
# Overlap:38310
# Error:0.0005566632525011229
# Finding better homography...
# best score: 55.000000
# Overlap:55742
# Error:0.00045446985272156734
# best score: 3169.000000
# best score: 155.000000
# Overlap:146026
# Error:0.00029765994578919976
# Found better homography
# best score: 36.000000
# Overlap:25341
# Error:0.0007025889823068447
# Finding better homography...
# best score: 70.000000
# Overlap:42848
# Error:0.0005254693745934753
# best score: 2594.000000
# best score: 291.000000
# Overlap:147225
# Error:0.00018254561543138128
# Found better homography
# best score: 27.000000
# Overlap:38476
# Error:0.0005323201568361066
# Finding better homography...
# best score: 52.000000
# Overlap:55119
# Error:0.0004551389156459487
# best score: 3141.000000
# best score: 115.000000
# Overlap:145366
# Error:0.00029984830714484555
# Found better homography
# best score: 39.000000
# Overlap:25894
# Error:0.000715291986306804
# Finding better homography...
# best score: 75.000000
# Overlap:43944
# Error:0.0005148293744884403
# best score: 2590.000000
# best score: 292.000000
# Overlap:147555
# Error:0.0001797721146746239
# Found better homography
# best score: 26.000000
# Overlap:39156
# Error:0.0005262437115477436
# Finding better homography...
# best score: 50.000000
# Overlap:56188
# Error:0.00045739865788015386
# best score: 3164.000000
# best score: 129.000000
# Overlap:145082
# Error:0.00030038224387224203
# Found better homography
# best score: 47.000000
# Overlap:26711
# Error:0.0007088642064020865
# Finding better homography...
# Overlap:43944
# Error:0.0005148289160359437
# best score: 297.000000
# Overlap:147663
# Error:0.00018144518839813254
# Found better homography
# best score: 22.000000
# Overlap:39533
# Error:0.0005295525389084964
# Finding better homography...
# Overlap:56188
# Error:0.00045740169037271946
# best score: 126.000000
# Overlap:145836
# Error:0.0003003759749840648
# Found better homography
# best score: 38.000000
# Overlap:26463
# Error:0.0007145758188247276
# Finding better homography...
# best score: 68.000000
# Overlap:44306
# Error:0.0005157001473179549
# best score: 2630.000000
# best score: 292.000000
# Overlap:147593
# Error:0.0001777994304836219
# Found better homography
# best score: 22.000000
# Overlap:40389
# Error:0.0005298903123652247
# Finding better homography...
# best score: 56.000000
# Overlap:56576
# Error:0.0004362516752752924
# best score: 3205.000000
# best score: 158.000000
# Overlap:147171
# Error:0.0002941353544734793
# Found better homography
# best score: 39.000000
# Overlap:26966
# Error:0.0007032968588869219
# Finding better homography...
# best score: 77.000000
# Overlap:42779
# Error:0.0005221542422592656
# best score: 2609.000000
# best score: 289.000000
# Overlap:148833
# Error:0.00017795009886384402
# Found better homography
# best score: 30.000000
# Overlap:40443
# Error:0.0005226186579817614
# Finding better homography...
# best score: 52.000000
# Overlap:57481
# Error:0.00043065235132382003
# best score: 3178.000000
# best score: 141.000000
# Overlap:148023
# Error:0.0002936199822703548
# Found better homography
# best score: 38.000000
# Overlap:29275
# Error:0.0007573797754664402
# Finding better homography...
# best score: 64.000000
# Overlap:42483
# Error:0.0005220828398716794
# best score: 2610.000000
# best score: 313.000000
# Overlap:149987
# Error:0.00017845001314473012
# Found better homography
# best score: 29.000000
# Overlap:41781
# Error:0.0005235422631083454
# Finding better homography...
# best score: 56.000000
# Overlap:55211
# Error:0.00046633392070245263
# best score: 3245.000000
# best score: 132.000000
# Overlap:150285
# Error:0.0002906214038568628
# Found better homography
# best score: 40.000000
# Overlap:27716
# Error:0.000712960251020986
# Finding better homography...
# Overlap:42483
# Error:0.0005220814152922425
# best score: 304.000000
# Overlap:149165
# Error:0.00017730759833648426
# Found better homography
# best score: 25.000000
# Overlap:40846
# Error:0.0005295534959958609
# Finding better homography...
# Overlap:55211
# Error:0.00046633283012031745
# best score: 140.000000
# Overlap:150081
# Error:0.00029200548817814273
# Found better homography
# best score: 43.000000
# Overlap:27364
# Error:0.0007136059651942747
# Finding better homography...
# best score: 65.000000
# Overlap:43420
# Error:0.0005059759167993894
# best score: 2612.000000
# best score: 286.000000
# Overlap:149489
# Error:0.00017969596126778163
# Found better homography
# best score: 27.000000
# Overlap:41658
# Error:0.0005209592362013759
# Finding better homography...
# best score: 56.000000
# Overlap:55440
# Error:0.0004541209859357256
# best score: 3145.000000
# best score: 147.000000
# Overlap:150267
# Error:0.0002903212218984247
# Found better homography
# best score: 45.000000
# Overlap:26609
# Error:0.0007048964880286487
# Finding better homography...
# best score: 65.000000
# Overlap:43618
# Error:0.0005101717284171902
# best score: 2581.000000
# best score: 341.000000
# Overlap:149129
# Error:0.00017669505339769513
# Found better homography
# best score: 29.000000
# Overlap:41561
# Error:0.0005170235205311125
# Finding better homography...
# best score: 60.000000
# Overlap:56032
# Error:0.0004483913190786714
# best score: 3188.000000
# best score: 144.000000
# Overlap:149981
# Error:0.0002900116311460153
# Found better homography
# best score: 43.000000
# Overlap:27650
# Error:0.0007382198378766856
# Finding better homography...
# best score: 69.000000
# Overlap:43870
# Error:0.0004998137937139467
# best score: 2644.000000
# best score: 297.000000
# Overlap:149921
# Error:0.00017960617945127495
# Found better homography
# best score: 32.000000
# Overlap:41418
# Error:0.000516788631145439
# Finding better homography...
# best score: 48.000000
# Overlap:56882
# Error:0.0004497355127030316
# best score: 3117.000000
# best score: 132.000000
# Overlap:148955
# Error:0.0002938186391668714
# Found better homography
# best score: 43.000000
# Overlap:27989
# Error:0.000762262449678493
# Finding better homography...
# Overlap:43870
# Error:0.0004998137937139467
# best score: 298.000000
# Overlap:150352
# Error:0.00017950457447663004
# Found better homography
# best score: 28.000000
# Overlap:41892
# Error:0.0005260544046668107
# Finding better homography...
# Overlap:56882
# Error:0.0004497361289636531
# best score: 141.000000
# Overlap:149858
# Error:0.00029020580849942076
# Found better homography
# best score: 48.000000
# Overlap:26600
# Error:0.000740063239843658
# Finding better homography...
# best score: 59.000000
# Overlap:43755
# Error:0.0004961703636971694
# best score: 2579.000000
# best score: 249.000000
# Overlap:149900
# Error:0.00018335824821581834
# Found better homography
# best score: 39.000000
# Overlap:41877
# Error:0.0005174389330548063
# Finding better homography...
# best score: 49.000000
# Overlap:57387
# Error:0.00044857905461237983
# best score: 3194.000000
# best score: 145.000000
# Overlap:147207
# Error:0.00029755160266108413
# Found better homography
# best score: 39.000000
# Overlap:26317
# Error:0.0007395343408824224
# Finding better homography...
# best score: 77.000000
# Overlap:43744
# Error:0.0004921267755467251
# best score: 2579.000000
# best score: 273.000000
# Overlap:148682
# Error:0.0001790707909945352
# Found better homography
# best score: 34.000000
# Overlap:42230
# Error:0.0005149462141273617
# Finding better homography...
# best score: 57.000000
# Overlap:57446
# Error:0.0004492536187086752
# best score: 3190.000000
# best score: 128.000000
# Overlap:147299
# Error:0.00029756616179596126
# Found better homography
# best score: 37.000000
# Overlap:25574
# Error:0.0007466223678180562
# Finding better homography...
# best score: 68.000000
# Overlap:43816
# Error:0.0004917127059900173
# best score: 2513.000000
# best score: 251.000000
# Overlap:149779
# Error:0.0001821517289724173
# Found better homography
# best score: 31.000000
# Overlap:41925
# Error:0.0005134301304893135
# Finding better homography...
# best score: 62.000000
# Overlap:57718
# Error:0.00045015597777589095
# best score: 3142.000000
# best score: 115.000000
# Overlap:148079
# Error:0.00029297784283864565
# Found better homography
# best score: 36.000000
# Overlap:27274
# Error:0.0007280017954456796
# Finding better homography...
# Overlap:43816
# Error:0.0004917119007404512
# best score: 237.000000
# Overlap:150171
# Error:0.00018836472119163053
# Found better homography
# best score: 28.000000
# Overlap:41629
# Error:0.0005144819381283916
# Finding better homography...
# Overlap:57718
# Error:0.0004501558475732981
# best score: 158.000000
# Overlap:148380
# Error:0.0002923665196530324
# Found better homography
# best score: 45.000000
# Overlap:27917
# Error:0.0007357822935456921
# Finding better homography...
# best score: 73.000000
# Overlap:43646
# Error:0.0004984070814567571
# best score: 2586.000000
# best score: 282.000000
# Overlap:150629
# Error:0.0001874549682196778
# Found better homography
# best score: 32.000000
# Overlap:42287
# Error:0.0005113125025580184
# Finding better homography...
# best score: 62.000000
# Overlap:58002
# Error:0.00044763407772513804
# best score: 3155.000000
# best score: 141.000000
# Overlap:148485
# Error:0.00029298357267961133
# Found better homography
# best score: 35.000000
# Overlap:26436
# Error:0.0007273964948410826
# Finding better homography...
# best score: 64.000000
# Overlap:44307
# Error:0.0004927823435472323
# best score: 2601.000000
# best score: 249.000000
# Overlap:150357
# Error:0.00018844615094388786
# Found better homography
# best score: 28.000000
# Overlap:42002
# Error:0.0005352027801180586
# Finding better homography...
# best score: 55.000000
# Overlap:58357
# Error:0.0004499526792422283
# best score: 3170.000000
# best score: 144.000000
# Overlap:148656
# Error:0.00029469808816342245
# Found better homography
# best score: 41.000000
# Overlap:27112
# Error:0.0007270959773384897
# Finding better homography...
# best score: 58.000000
# Overlap:44921
# Error:0.0004926902354694389
# best score: 2596.000000
# best score: 274.000000
# Overlap:149749
# Error:0.00018554426972059435
# Found better homography
# best score: 42.000000
# Overlap:42759
# Error:0.000521846268832759
# Finding better homography...
# best score: 59.000000
# Overlap:58219
# Error:0.00043960117792080094
# best score: 3134.000000
# best score: 169.000000
# Overlap:147714
# Error:0.00029461211085881456
# Found better homography
# best score: 42.000000
# Overlap:26207
# Error:0.0007463804407409281
# Finding better homography...
# Overlap:44921
# Error:0.0004926888337801993
# best score: 252.000000
# Overlap:148290
# Error:0.00017923970215512827
# Found better homography
# best score: 40.000000
# Overlap:43137
# Error:0.0005075052419999173
# Finding better homography...
# Overlap:58219
# Error:0.00043960109193350814
# best score: 170.000000
# Overlap:147247
# Error:0.00029456942293682614
# Found better homography
# best score: 38.000000
# Overlap:25095
# Error:0.000765860969081115
# Finding better homography...
# best score: 66.000000
# Overlap:46865
# Error:0.000489939098207639
# best score: 2518.000000
# best score: 231.000000
# Overlap:148032
# Error:0.0001888133276624568
# Found better homography
# best score: 36.000000
# Overlap:42315
# Error:0.0005061818807580113
# Finding better homography...
# best score: 56.000000
# Overlap:59343
# Error:0.00043881233908161393
# best score: 3180.000000
# best score: 158.000000
# Overlap:146583
# Error:0.0002937626943855045
# Found better homography
# best score: 35.000000
# Overlap:26032
# Error:0.0007758111150407709
# Finding better homography...
# best score: 68.000000
# Overlap:45434
# Error:0.00048424425956052677
# best score: 2610.000000
# best score: 248.000000
# Overlap:147228
# Error:0.00018847281879601953
# Found better homography
# best score: 37.000000
# Overlap:42920
# Error:0.0005120115420268268
# Finding better homography...
# best score: 68.000000
# Overlap:59498
# Error:0.0004244140158851713
# best score: 3187.000000
# best score: 157.000000
# Overlap:145323
# Error:0.00029815579125338327
# Found better homography
# best score: 41.000000
# Overlap:25332
# Error:0.0007614045799311734
# Finding better homography...
# best score: 63.000000
# Overlap:46640
# Error:0.0004738932939842411
# best score: 2449.000000
# best score: 253.000000
# Overlap:145427
# Error:0.0001884332470527691
# Found better homography
# best score: 37.000000
# Overlap:42643
# Error:0.0004900399459017139
# Finding better homography...
# best score: 62.000000
# Overlap:59735
# Error:0.00045219574227252184
# best score: 3148.000000
# best score: 146.000000
# Overlap:144127
# Error:0.00030363978164418175
# Found better homography
# best score: 44.000000
# Overlap:26045
# Error:0.0007672531499193044
# Finding better homography...
# Overlap:46640
# Error:0.0004738937803322039
# best score: 250.000000
# Overlap:145883
# Error:0.00018966324175423183
# Found better homography
# best score: 30.000000
# Overlap:43134
# Error:0.0005053015068558467
# Finding better homography...
# Overlap:59735
# Error:0.00045219532398972645
# best score: 156.000000
# Overlap:144552
# Error:0.00029740447292795084
# Found better homography
# best score: 40.000000
# Overlap:25932
# Error:0.0007577065157065972
# Finding better homography...
# best score: 56.000000
# Overlap:46121
# Error:0.0004885237704702228
# best score: 2437.000000
# best score: 261.000000
# Overlap:146271
# Error:0.0001920445938285778
# Found better homography
# best score: 39.000000
# Overlap:43494
# Error:0.000492288577181397
# Finding better homography...
# best score: 65.000000
# Overlap:60470
# Error:0.0004193656298579002
# best score: 3161.000000
# best score: 184.000000
# Overlap:144968
# Error:0.0002958186800047096
# Found better homography
# best score: 45.000000
# Overlap:26377
# Error:0.0007658927026623024
# Finding better homography...
# best score: 61.000000
# Overlap:47319
# Error:0.0004711606287302056
# best score: 2646.000000
# best score: 272.000000
# Overlap:144464
# Error:0.00019181019856389687
# Found better homography
# best score: 36.000000
# Overlap:43284
# Error:0.0005189384015627916
# Finding better homography...
# best score: 49.000000
# Overlap:61525
# Error:0.00041791131472017985
# best score: 3101.000000
# best score: 143.000000
# Overlap:144581
# Error:0.00029503922691258023
# Found better homography
# best score: 39.000000
# Overlap:25856
# Error:0.0007490640660310559
# Finding better homography...
# best score: 57.000000
# Overlap:46603
# Error:0.0004812795459744287
# best score: 2564.000000
# best score: 246.000000
# Overlap:144215
# Error:0.00019335270280036788
# Found better homography
# best score: 33.000000
# Overlap:42261
# Error:0.0005425404803157718
# Finding better homography...
# best score: 52.000000
# Overlap:61423
# Error:0.00042288419243978725
# best score: 3113.000000
# best score: 148.000000
# Overlap:143870
# Error:0.0002989772258538548
# Found better homography
# best score: 37.000000
# Overlap:25297
# Error:0.0007601062198707776
# Finding better homography...
# Overlap:46604
# Error:0.00048127786538960905
# best score: 243.000000
# Overlap:143727
# Error:0.00019010745181804523
# Found better homography
# best score: 39.000000
# Overlap:43623
# Error:0.0005133929646103775
# Finding better homography...
# Overlap:61423
# Error:0.00042288419243978725
# best score: 154.000000
# Overlap:143619
# Error:0.0002984317960908363
# Found better homography
# best score: 41.000000
# Overlap:26618
# Error:0.0007460924364630367
# Finding better homography...
# best score: 65.000000
# Overlap:46761
# Error:0.00048101998475508413
# best score: 2490.000000
# best score: 249.000000
# Overlap:144777
# Error:0.00019187708837888276
# Found better homography
# best score: 36.000000
# Overlap:43321
# Error:0.0005071676787154288
# Finding better homography...
# best score: 51.000000
# Overlap:62423
# Error:0.00042423229208709743
# best score: 3113.000000
# best score: 154.000000
# Overlap:143758
# Error:0.00029789197863267945
# Found better homography
# best score: 46.000000
# Overlap:26603
# Error:0.0007438076242572209
# Finding better homography...
# best score: 57.000000
# Overlap:49631
# Error:0.000467712669623133
# best score: 2557.000000
# best score: 264.000000
# Overlap:143431
# Error:0.00019422178019740037
# Found better homography
# best score: 34.000000
# Overlap:43213
# Error:0.0005001519346048612
# Finding better homography...
# best score: 66.000000
# Overlap:62052
# Error:0.0004240737572011959
# best score: 3149.000000
# best score: 151.000000
# Overlap:143474
# Error:0.0002975353581131438
# Found better homography
# best score: 38.000000
# Overlap:27767
# Error:0.0007612139180681987
# Finding better homography...
# best score: 71.000000
# Overlap:49625
# Error:0.0004644174715323192
# best score: 2523.000000
# best score: 259.000000
# Overlap:142623
# Error:0.00019294643674603958
# Found better homography
# best score: 42.000000
# Overlap:43727
# Error:0.0004965693924943208
# Finding better homography...
# best score: 57.000000
# Overlap:62648
# Error:0.0004229669971686694
# best score: 3100.000000
# best score: 125.000000
# Overlap:143960
# Error:0.0002981438792407498
# Found better homography
# best score: 43.000000
# Overlap:26833
# Error:0.0007457728017475075
# Finding better homography...
# Overlap:49625
# Error:0.00046441711623529424
# best score: 272.000000
# Overlap:141817
# Error:0.0001912459592144829
# Found better homography
# best score: 44.000000
# Overlap:44587
# Error:0.0004896920935032037
# Finding better homography...
# Overlap:62648
# Error:0.0004229665583033367
# best score: 152.000000
# Overlap:144377
# Error:0.00029878821151462946
# Found better homography
# best score: 40.000000
# Overlap:27128
# Error:0.0007649735456323022
# Finding better homography...
# best score: 69.000000
# Overlap:49405
# Error:0.0004612147549445842
# best score: 2625.000000
# best score: 259.000000
# Overlap:141025
# Error:0.0001936031736499478
# Found better homography
# best score: 44.000000
# Overlap:44976
# Error:0.0005048498548213046
# Finding better homography...
# best score: 65.000000
# Overlap:63826
# Error:0.0004239696976608442
# best score: 3023.000000
# best score: 182.000000
# Overlap:143257
# Error:0.00029674146259637646
# Found better homography
# best score: 38.000000
# Overlap:26560
# Error:0.0007706389213248025
# Finding better homography...
# best score: 68.000000
# Overlap:50163
# Error:0.0004682703488401981
# best score: 2679.000000
# best score: 238.000000
# Overlap:140486
# Error:0.00019638642538614094
# Found better homography
# best score: 43.000000
# Overlap:45154
# Error:0.0004992648810611502
# Finding better homography...
# best score: 60.000000
# Overlap:64910
# Error:0.0004169419022256298
# best score: 3087.000000
# best score: 163.000000
# Overlap:143176
# Error:0.0002952927944288654
# Found better homography
# best score: 42.000000
# Overlap:27130
# Error:0.0007650691052395506
# Finding better homography...
# best score: 57.000000
# Overlap:51723
# Error:0.00046814877880109316
# best score: 2634.000000
# best score: 243.000000
# Overlap:138749
# Error:0.00019608299850671629
# Found better homography
# best score: 41.000000
# Overlap:44809
# Error:0.0004998379918179949
# Finding better homography...
# best score: 64.000000
# Overlap:64034
# Error:0.0004397025392670836
# best score: 3096.000000
# best score: 137.000000
# Overlap:141794
# Error:0.0002983695732849748
# Found better homography
# best score: 39.000000
# Overlap:26911
# Error:0.0007531000245030704
# Finding better homography...
# Overlap:51723
# Error:0.00046814868142093535
# best score: 263.000000
# Overlap:139840
# Error:0.00019783789874149412
# Found better homography
# best score: 31.000000
# Overlap:44613
# Error:0.0005125911907874695
# Finding better homography...
# Overlap:64034
# Error:0.0004397032019808286
# best score: 138.000000
# Overlap:142801
# Error:0.00029560030751146077
# Found better homography
# best score: 43.000000
# Overlap:26545
# Error:0.0007484736861055464
# Finding better homography...
# best score: 60.000000
# Overlap:51312
# Error:0.0004640383007988474
# best score: 2600.000000
# best score: 255.000000
# Overlap:139484
# Error:0.00019574203213292894
# Found better homography
# best score: 31.000000
# Overlap:43597
# Error:0.0005472648775177836
# Finding better homography...
# best score: 59.000000
# Overlap:64577
# Error:0.0004465794257812896
# best score: 3015.000000
# best score: 136.000000
# Overlap:142554
# Error:0.00029594066270638225
# Found better homography
# best score: 35.000000
# Overlap:28182
# Error:0.000772123702311765
# Finding better homography...
# best score: 76.000000
# Overlap:52584
# Error:0.00046624972756958527
# best score: 2602.000000
# best score: 239.000000
# Overlap:140571
# Error:0.00020007686821496727
# Found better homography
# best score: 47.000000
# Overlap:45431
# Error:0.0005128234847355112
# Finding better homography...
# best score: 63.000000
# Overlap:66108
# Error:0.0004217391173891832
# best score: 3191.000000
# best score: 165.000000
# Overlap:142709
# Error:0.0002945680463083904
# Found better homography
# best score: 40.000000
# Overlap:28064
# Error:0.0007573001069489734
# Finding better homography...
# best score: 72.000000
# Overlap:52747
# Error:0.0004656994455469679
# best score: 2558.000000
# best score: 247.000000
# Overlap:139461
# Error:0.0002006679655902232
# Found better homography
# best score: 38.000000
# Overlap:45430
# Error:0.0005153822552583928
# Finding better homography...
# best score: 62.000000
# Overlap:66060
# Error:0.0004322566006410308
# best score: 3166.000000
# best score: 157.000000
# Overlap:143401
# Error:0.00029452270618893597
# Found better homography
# best score: 42.000000
# Overlap:28394
# Error:0.0007555204651494455
# Finding better homography...
# Overlap:52747
# Error:0.00046570049609888435
# best score: 239.000000
# Overlap:139447
# Error:0.00019695537732879184
# Found better homography
# best score: 39.000000
# Overlap:45751
# Error:0.0005194372815316332
# Finding better homography...
# Overlap:66060
# Error:0.0004322566385064739
# best score: 151.000000
# Overlap:143270
# Error:0.00029956931133308075
# Found better homography
# best score: 56.000000
# Overlap:28588
# Error:0.000731189111729908
# Finding better homography...
# best score: 80.000000
# Overlap:52980
# Error:0.0004648139496861233
# best score: 2655.000000
# best score: 264.000000
# Overlap:140132
# Error:0.00019823721310705073
# Found better homography
# best score: 41.000000
# Overlap:45972
# Error:0.0005079385228554672
# Finding better homography...
# best score: 74.000000
# Overlap:66396
# Error:0.00042938019566074475
# best score: 3170.000000
# best score: 160.000000
# Overlap:143716
# Error:0.0002984752201215796
# Found better homography
# best score: 51.000000
# Overlap:29370
# Error:0.0007338540679518892
# Finding better homography...
# best score: 69.000000
# Overlap:54651
# Error:0.0004699077903552949
# best score: 2608.000000
# best score: 269.000000
# Overlap:140445
# Error:0.0001988709298390441
# Found better homography
# best score: 42.000000
# Overlap:46083
# Error:0.000511852637708422
# Finding better homography...
# best score: 62.000000
# Overlap:66039
# Error:0.0004372080328466534
# best score: 3161.000000
# best score: 163.000000
# Overlap:143578
# Error:0.0002969991101330806
# Found better homography
# best score: 42.000000
# Overlap:30175
# Error:0.0007439895357093128
# Finding better homography...
# best score: 70.000000
# Overlap:54175
# Error:0.00046018234455423216
# best score: 2675.000000
# best score: 249.000000
# Overlap:139236
# Error:0.00019889580073963756
# Found better homography
# best score: 34.000000
# Overlap:45003
# Error:0.000516974238808209
# Finding better homography...
# best score: 64.000000
# Overlap:65907
# Error:0.0004366649477841783
# best score: 3149.000000
# best score: 167.000000
# Overlap:143502
# Error:0.00029767186397978675
# Found better homography
# best score: 47.000000
# Overlap:29868
# Error:0.0007315153857002494
# Finding better homography...
# Overlap:54175
# Error:0.00046018383210998337
# best score: 256.000000
# Overlap:138820
# Error:0.00019960818479463046
# Found better homography
# best score: 47.000000
# Overlap:46406
# Error:0.0005145470786713046
# Finding better homography...
# Overlap:65907
# Error:0.0004366649477841783
# best score: 167.000000
# Overlap:143756
# Error:0.0002988250987282683
# Found better homography
# best score: 47.000000
# Overlap:29790
# Error:0.0007082111136626725
# Finding better homography...
# best score: 71.000000
# Overlap:53249
# Error:0.00046677555224354267
# best score: 2606.000000
# best score: 255.000000
# Overlap:138993
# Error:0.0002007638878186986
# Found better homography
# best score: 42.000000
# Overlap:47049
# Error:0.0005118859120589636
# Finding better homography...
# best score: 53.000000
# Overlap:66955
# Error:0.0004625253386608956
# best score: 3124.000000
# best score: 134.000000
# Overlap:144679
# Error:0.0002988819806009466
# Found better homography
# best score: 40.000000
# Overlap:29403
# Error:0.0007066339921396336
# Finding better homography...
# best score: 80.000000
# Overlap:53393
# Error:0.0004685027230321133
# best score: 2579.000000
# best score: 250.000000
# Overlap:139137
# Error:0.0002011754192084459
# Found better homography
# best score: 44.000000
# Overlap:47436
# Error:0.0005108366432003528
# Finding better homography...
# best score: 59.000000
# Overlap:66973
# Error:0.000437064709301745
# best score: 3202.000000
# best score: 160.000000
# Overlap:143896
# Error:0.00030132134103501204
# Found better homography
# best score: 59.000000
# Overlap:30314
# Error:0.0007106729548054557
# Finding better homography...
# best score: 84.000000
# Overlap:54910
# Error:0.00044893885283866424
# best score: 2671.000000
# best score: 273.000000
# Overlap:139712
# Error:0.00019940935308646545
# Found better homography
# best score: 42.000000
# Overlap:45977
# Error:0.000533975002774882
# Finding better homography...
# best score: 65.000000
# Overlap:66848
# Error:0.0004460807323121349
# best score: 3151.000000
# best score: 157.000000
# Overlap:142244
# Error:0.00030541287464324495
# Found better homography
# best score: 51.000000
# Overlap:30202
# Error:0.0007004427696611381
# Finding better homography...
# Overlap:54910
# Error:0.0004489387611298414
# best score: 254.000000
# Overlap:140038
# Error:0.00019936917596796177
# Found better homography
# best score: 34.000000
# Overlap:46342
# Error:0.0005312972264152994
# Finding better homography...
# Overlap:66848
# Error:0.0004460807323121349
# best score: 152.000000
# Overlap:142641
# Error:0.0003052830101060392
# Found better homography
# best score: 45.000000
# Overlap:31196
# Error:0.0006893775101528719
# Finding better homography...
# best score: 72.000000
# Overlap:55187
# Error:0.0004550801377418889
# best score: 2599.000000
# best score: 244.000000
# Overlap:141002
# Error:0.0001984864429539141
# Found better homography
# best score: 38.000000
# Overlap:46678
# Error:0.0005172703098489954
# Finding better homography...
# best score: 65.000000
# Overlap:67496
# Error:0.0004439382931974965
# best score: 3120.000000
# best score: 160.000000
# Overlap:142653
# Error:0.000305547115305379
# Found better homography
# best score: 52.000000
# Overlap:30962
# Error:0.0007164787208388865
# Finding better homography...
# best score: 82.000000
# Overlap:55475
# Error:0.00045149974196564193
# best score: 2538.000000
# best score: 246.000000
# Overlap:142230
# Error:0.00019991809751554769
# Found better homography
# best score: 38.000000
# Overlap:47609
# Error:0.0005198113279027746
# Finding better homography...
# best score: 71.000000
# Overlap:67545
# Error:0.0004433251531043308
# best score: 3123.000000
# best score: 171.000000
# Overlap:143379
# Error:0.0003031510125883373
# Found better homography
# best score: 41.000000
# Overlap:33084
# Error:0.0007018955123101972
# Finding better homography...
# best score: 60.000000
# Overlap:55598
# Error:0.0004529582471305727
# best score: 2551.000000
# best score: 243.000000
# Overlap:142442
# Error:0.00019910187432604934
# Found better homography
# best score: 41.000000
# Overlap:47900
# Error:0.0005154294264642833
# Finding better homography...
# best score: 68.000000
# Overlap:67657
# Error:0.0004447241298753186
# best score: 3136.000000
# best score: 166.000000
# Overlap:143867
# Error:0.0003033391212461656
# Found better homography
# best score: 56.000000
# Overlap:32017
# Error:0.0006793918818270602
# Finding better homography...
# Overlap:55598
# Error:0.0004529589267972629
# best score: 263.000000
# Overlap:143496
# Error:0.0001980070627189371
# Found better homography
# best score: 33.000000
# Overlap:46518
# Error:0.0005371346493861737
# Finding better homography...
# Overlap:67657
# Error:0.0004447242038440566
# best score: 179.000000
# Overlap:144083
# Error:0.0003067032178425543
# Found better homography
# best score: 50.000000
# Overlap:32084
# Error:0.0006812892590835554
# Finding better homography...
# best score: 72.000000
# Overlap:55127
# Error:0.00044851066567477724
# best score: 2687.000000
# best score: 263.000000
# Overlap:141512
# Error:0.00019874522802611647
# Found better homography
# best score: 41.000000
# Overlap:49397
# Error:0.000520921341387444
# Finding better homography...
# best score: 59.000000
# Overlap:67789
# Error:0.0004446603212841214
# best score: 3091.000000
# best score: 153.000000
# Overlap:143604
# Error:0.0003107524004424889
# Found better homography
# best score: 53.000000
# Overlap:31380
# Error:0.0006735475882603065
# Finding better homography...
# best score: 75.000000
# Overlap:55766
# Error:0.0004588160083826421
# best score: 2633.000000
# best score: 243.000000
# Overlap:142088
# Error:0.00020901791203169329
# Found better homography
# best score: 36.000000
# Overlap:49909
# Error:0.0005060803313377374
# Finding better homography...
# best score: 73.000000
# Overlap:67793
# Error:0.00045046509529705214
# best score: 3099.000000
# best score: 185.000000
# Overlap:145859
# Error:0.00029843801510585856
# Found better homography
# /home/kazukis2/anaconda3/envs/cv3/lib/python3.6/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in true_divide
# /home/kazukis2/anaconda3/envs/cv3/lib/python3.6/site-packages/ipykernel_launcher.py:61: RuntimeWarning: divide by zero encountered in true_divide
# best score: 45.000000
# Overlap:31526
# Error:0.0006814946966892452
# Finding better homography...
# best score: 72.000000
# Overlap:55356
# Error:0.00045357909572522805
# best score: 2730.000000
# best score: 247.000000
# Overlap:141055
# Error:0.0002001853246681558
# Found better homography
# best score: 37.000000
# Overlap:50635
# Error:0.0004972895493937626
# Finding better homography...
# best score: 56.000000
# Overlap:68699
# Error:0.0004460862676517574
# best score: 3043.000000
# best score: 173.000000
# Overlap:145765
# Error:0.00029964953217860634
# Found better homography
# best score: 46.000000
# Overlap:31729
# Error:0.0006696429610603243
# Finding better homography...
# Overlap:55356
# Error:0.00045357936866500235
# best score: 247.000000
# Overlap:143229
# Error:0.00020230680436927295
# Found better homography
# best score: 46.000000
# Overlap:51125
# Error:0.000505606520970355
# Finding better homography...
# Overlap:68699
# Error:0.000446086449486709
# best score: 154.000000
# Overlap:146157
# Error:0.00030298602969007954
# Found better homography
# best score: 44.000000
# Overlap:32723
# Error:0.0006826123325004917
# Finding better homography...
# best score: 63.000000
# Overlap:55871
# Error:0.00045384256438389437
# best score: 2658.000000
# best score: 256.000000
# Overlap:143503
# Error:0.00020064049065863582
# Found better homography
# best score: 49.000000
# Overlap:51310
# Error:0.0004997642675291467
# Finding better homography...
# best score: 72.000000
# Overlap:69066
# Error:0.00044252354383950073
# best score: 3159.000000
# best score: 149.000000
# Overlap:145595
# Error:0.00030494427816400775
# Found better homography
# best score: 47.000000
# Overlap:32416
# Error:0.0006680845314359439
# Finding better homography...
# best score: 77.000000
# Overlap:56403
# Error:0.0004594037603863651
# best score: 2601.000000
# best score: 245.000000
# Overlap:144493
# Error:0.00020062929725069925
# Found better homography
# best score: 54.000000
# Overlap:51340
# Error:0.0005064176943718177
# Finding better homography...
# best score: 68.000000
# Overlap:69729
# Error:0.0004424097778690699
# best score: 3123.000000
# best score: 168.000000
# Overlap:145502
# Error:0.000300635827857288
# Found better homography
# best score: 45.000000
# Overlap:31765
# Error:0.0006772108797477196
# Finding better homography...
# best score: 83.000000
# Overlap:54728
# Error:0.0004563224223666716
# best score: 2616.000000
# best score: 275.000000
# Overlap:143714
# Error:0.00019893249018062919
# Found better homography
# best score: 47.000000
# Overlap:51045
# Error:0.0005056505703730647
# Finding better homography...
# best score: 64.000000
# Overlap:69614
# Error:0.00044850412376180285
# best score: 2996.000000
# best score: 176.000000
# Overlap:145455
# Error:0.0003046627793672173
# Found better homography
# best score: 48.000000
# Overlap:33927
# Error:0.0006728617941858325
# Finding better homography...
# Overlap:54728
# Error:0.00045632334285174793
# best score: 266.000000
# Overlap:144066
# Error:0.00019723795966853207
# Found better homography
# best score: 52.000000
# Overlap:52171
# Error:0.0004897531748473535
# Finding better homography...
# Overlap:69614
# Error:0.0004485038005964856
# best score: 134.000000
# Overlap:146774
# Error:0.0002968090338368427
# Found better homography
# best score: 41.000000
# Overlap:32437
# Error:0.0006521008700682572
# Finding better homography...
# best score: 64.000000
# Overlap:54673
# Error:0.00045755897125057085
# best score: 2645.000000
# best score: 270.000000
# Overlap:144568
# Error:0.00019890129554979544
# Found better homography
# best score: 42.000000
# Overlap:52537
# Error:0.0004977770902355381
# Finding better homography...
# best score: 56.000000
# Overlap:69743
# Error:0.00044538455009684433
# best score: 3047.000000
# best score: 153.000000
# Overlap:146575
# Error:0.0003007175850154152
# Found better homography
# best score: 42.000000
# Overlap:32330
# Error:0.0006542278939710918
# Finding better homography...
# best score: 75.000000
# Overlap:54874
# Error:0.0004534941765529912
# best score: 2590.000000
# best score: 232.000000
# Overlap:142370
# Error:0.0001991021734445828
# Found better homography
# best score: 34.000000
# Overlap:50882
# Error:0.0005521086218400126
# Finding better homography...
# best score: 67.000000
# Overlap:69682
# Error:0.0004523592334796486
# best score: 3046.000000
# best score: 162.000000
# Overlap:147049
# Error:0.00029879253828691594
# Found better homography
# best score: 37.000000
# Overlap:32736
# Error:0.0006344483135556581
# Finding better homography...
# best score: 73.000000
# Overlap:54659
# Error:0.00047634680571601295
# best score: 2695.000000
# best score: 241.000000
# Overlap:143437
# Error:0.00020019136074795414
# Found better homography
# best score: 36.000000
# Overlap:52856
# Error:0.0004981128351503774
# Finding better homography...
# best score: 60.000000
# Overlap:69337
# Error:0.00045486350391085007
# best score: 3086.000000
# best score: 160.000000
# Overlap:148005
# Error:0.0002950185096679705
# Found better homography
# best score: 52.000000
# Overlap:33114
# Error:0.0006360196843424768
# Finding better homography...
# Overlap:54659
# Error:0.00047634652930536635
# best score: 250.000000
# Overlap:144016
# Error:0.00019969015376896277
# Found better homography
# best score: 51.000000
# Overlap:53885
# Error:0.0004695697184242803
# Finding better homography...
# Overlap:69337
# Error:0.00045486285442563864
# best score: 166.000000
# Overlap:148121
# Error:0.00029829536885950903
# Found better homography
# best score: 50.000000
# Overlap:32810
# Error:0.0006357052439575257
# Finding better homography...
# best score: 68.000000
# Overlap:56290
# Error:0.0004525285833719826
# best score: 2638.000000
# best score: 250.000000
# Overlap:140838
# Error:0.0001962733425499372
# Found better homography
# best score: 45.000000
# Overlap:53839
# Error:0.00047825371254375706
# Finding better homography...
# best score: 62.000000
# Overlap:69631
# Error:0.000449164702393315
# best score: 3131.000000
# best score: 190.000000
# Overlap:149123
# Error:0.00029562367533385764
# Found better homography
# best score: 50.000000
# Overlap:32757
# Error:0.0006337094530844592
# Finding better homography...
# best score: 78.000000
# Overlap:56172
# Error:0.00046479645796123405
# best score: 2672.000000
# best score: 247.000000
# Overlap:140950
# Error:0.000197704815899863
# Found better homography
# best score: 44.000000
# Overlap:54464
# Error:0.0004657168120259815
# Finding better homography...
# best score: 64.000000
# Overlap:70897
# Error:0.0004456392552759153
# best score: 2977.000000
# best score: 171.000000
# Overlap:147729
# Error:0.000298728818119157
# Found better homography
# best score: 56.000000
# Overlap:33140
# Error:0.0006274448933735968
# Finding better homography...
# best score: 80.000000
# Overlap:56583
# Error:0.00046019815870564047
# best score: 2594.000000
# best score: 213.000000
# Overlap:139790
# Error:0.0001981605386616468
# Found better homography
# best score: 44.000000
# Overlap:54485
# Error:0.00046427990515122866
# Finding better homography...
# best score: 74.000000
# Overlap:71934
# Error:0.00043973406636084613
# best score: 2959.000000
# best score: 174.000000
# Overlap:146704
# Error:0.0002999162190951821
# Found better homography
# best score: 50.000000
# Overlap:33368
# Error:0.0006156899794021493
# Finding better homography...
# Overlap:56583
# Error:0.0004601982477586567
# best score: 225.000000
# Overlap:139307
# Error:0.00019537238651621468
# Found better homography
# best score: 33.000000
# Overlap:53925
# Error:0.0005014288415111048
# Finding better homography...
# Overlap:71934
# Error:0.00043973330068235216
# best score: 176.000000
# Overlap:146480
# Error:0.00030056094548466594
# Found better homography
# best score: 50.000000
# Overlap:33819
# Error:0.0006170072178195215
# Finding better homography...
# best score: 94.000000
# Overlap:56837
# Error:0.0004527376701134308
# best score: 2755.000000
# best score: 255.000000
# Overlap:141619
# Error:0.00019652282905986365
# Found better homography
# best score: 46.000000
# Overlap:54783
# Error:0.00046714346960461035
# Finding better homography...
# best score: 79.000000
# Overlap:72368
# Error:0.0004480130282164308
# best score: 2935.000000
# best score: 158.000000
# Overlap:145949
# Error:0.00030343300846508706
# Found better homography
# best score: 49.000000
# Overlap:34641
# Error:0.0006055896256234239
# Finding better homography...
# best score: 76.000000
# Overlap:56268
# Error:0.00046736589153703075
# best score: 2669.000000
# best score: 236.000000
# Overlap:141495
# Error:0.0001975632224080821
# Found better homography
# best score: 46.000000
# Overlap:54149
# Error:0.0004718376933799007
# Finding better homography...
# best score: 73.000000
# Overlap:72304
# Error:0.00044106121334314385
# best score: 3066.000000
# best score: 182.000000
# Overlap:144780
# Error:0.0003086375441813312
# Found better homography
# best score: 52.000000
# Overlap:34428
# Error:0.0005898556516531345
# Finding better homography...
# best score: 75.000000
# Overlap:59182
# Error:0.00045154867857372414
# best score: 2738.000000
# best score: 235.000000
# Overlap:141131
# Error:0.00019548793570724185
# Found better homography
# best score: 43.000000
# Overlap:53559
# Error:0.0004956711315833134
# Finding better homography...
# best score: 64.000000
# Overlap:73793
# Error:0.00044491795541472923
# best score: 3053.000000
# best score: 203.000000
# Overlap:144504
# Error:0.00030567368310337374
# Found better homography
# best score: 60.000000
# Overlap:34366
# Error:0.000590703652518262
# Finding better homography...
# Overlap:59182
# Error:0.0004515493599255541
# best score: 248.000000
# Overlap:141625
# Error:0.00019507215624603411
# Found better homography
# best score: 44.000000
# Overlap:54867
# Error:0.00045689033330491757
# Finding better homography...
# Overlap:73793
# Error:0.00044491798936675884
# best score: 185.000000
# Overlap:144171
# Error:0.00030644105547767233
# Found better homography
# best score: 59.000000
# Overlap:34371
# Error:0.000593746187321384
# Finding better homography...
# best score: 91.000000
# Overlap:57375
# Error:0.0004606481147825053
# best score: 2714.000000
# best score: 260.000000
# Overlap:142285
# Error:0.0001980464694900649
# Found better homography
# best score: 48.000000
# Overlap:54913
# Error:0.00048047765376458336
# Finding better homography...
# best score: 70.000000
# Overlap:73816
# Error:0.00043714077996310705
# best score: 3063.000000
# best score: 168.000000
# Overlap:144234
# Error:0.00030857918707974386
# Found better homography
# best score: 55.000000
# Overlap:35532
# Error:0.0005909182044315439
# Finding better homography...
# best score: 94.000000
# Overlap:57127
# Error:0.0004627772072498173
# best score: 2687.000000
# best score: 218.000000
# Overlap:143360
# Error:0.00020326646412217983
# Found better homography
# best score: 42.000000
# Overlap:54666
# Error:0.0004849514320025707
# Finding better homography...
# best score: 65.000000
# Overlap:74088
# Error:0.0004366666753851502
# best score: 2994.000000
# best score: 143.000000
# Overlap:144020
# Error:0.0003112369519666389
# Found better homography
# best score: 54.000000
# Overlap:35414
# Error:0.0005962842960389032
# Finding better homography...
# best score: 83.000000
# Overlap:58765
# Error:0.00044551640471064626
# best score: 2742.000000
# best score: 251.000000
# Overlap:142857
# Error:0.000200489949524794
# Found better homography
# best score: 45.000000
# Overlap:54428
# Error:0.00046908603983782104
# Finding better homography...
# best score: 65.000000
# Overlap:74646
# Error:0.0004343513380625393
# best score: 3006.000000
# best score: 151.000000
# Overlap:142434
# Error:0.0003154655540581519
# Found better homography
# best score: 54.000000
# Overlap:35503
# Error:0.0005805593709741862
# Finding better homography...
# Overlap:58765
# Error:0.0004455166618639123
# best score: 232.000000
# Overlap:142737
# Error:0.00020068160382342453
# Found better homography
# best score: 59.000000
# Overlap:54150
# Error:0.000462418224757214
# Finding better homography...
# Overlap:74646
# Error:0.0004343516734972114
# best score: 150.000000
# Overlap:141824
# Error:0.0003203515702513736
# Found better homography
# best score: 58.000000
# Overlap:36507
# Error:0.0005824988143504575
# Finding better homography...
# best score: 95.000000
# Overlap:58160
# Error:0.00045269604487752963
# best score: 2706.000000
# best score: 247.000000
# Overlap:141625
# Error:0.00019379211431789465
# Found better homography
# best score: 55.000000
# Overlap:54416
# Error:0.0004635898303881898
# Finding better homography...
# best score: 84.000000
# Overlap:75157
# Error:0.0004333525078153145
# best score: 3030.000000
# best score: 155.000000
# Overlap:141868
# Error:0.00031826952594062074
# Found better homography
# best score: 57.000000
# Overlap:35368
# Error:0.0005754043908007054
# Finding better homography...
# best score: 84.000000
# Overlap:58747
# Error:0.0004459606602438846
# best score: 2681.000000
# best score: 252.000000
# Overlap:141837
# Error:0.00019497888987803674
# Found better homography
# best score: 41.000000
# Overlap:54676
# Error:0.0004708413437490846
# Finding better homography...
# best score: 71.000000
# Overlap:75864
# Error:0.0004267491375153553
# best score: 2968.000000
# best score: 146.000000
# Overlap:141790
# Error:0.0003186921302418713
# Found better homography
# best score: 52.000000
# Overlap:37316
# Error:0.0005905183677945075
# Finding better homography...
# best score: 90.000000
# Overlap:58521
# Error:0.00045029242582806127
# best score: 2625.000000
# best score: 213.000000
# Overlap:143590
# Error:0.00020124546737811295
# Found better homography
# best score: 53.000000
# Overlap:55665
# Error:0.00045991166271202563
# Finding better homography...
# best score: 72.000000
# Overlap:75341
# Error:0.0004328525975869029
# best score: 2992.000000
# best score: 143.000000
# Overlap:141512
# Error:0.00031748989048037
# Found better homography
# best score: 61.000000
# Overlap:36154
# Error:0.0005816182625122026
# Finding better homography...
# Overlap:58521
# Error:0.00045029208146554777
# best score: 204.000000
# Overlap:143268
# Error:0.00020542763675427024
# Found better homography
# best score: 55.000000
# Overlap:54969
# Error:0.0004612108556514311
# Finding better homography...
# Overlap:75341
# Error:0.0004328526971778193
# best score: 146.000000
# Overlap:141794
# Error:0.000318608387234633
# Found better homography
# best score: 64.000000
# Overlap:36473
# Error:0.0005895737928486438
# Finding better homography...
# best score: 84.000000
# Overlap:58417
# Error:0.0004594860949430547
# best score: 2607.000000
# best score: 253.000000
# Overlap:142269
# Error:0.00019459767589614078
# Found better homography
# best score: 51.000000
# Overlap:54254
# ...
# Overlap:122622
# Error:0.0002756180383102371
# best score: 152.000000
# Overlap:129707
# Error:0.00033497639129573026
# best score: 160.000000
# Overlap:123874
# Error:0.00028437564439662727
# best score: 141.000000
# Overlap:129513
# Error:0.00033324849062459604
# best score: 189.000000
# Overlap:123907
# Error:0.0002729768546187349
# best score: 130.000000
# Overlap:129660
# Error:0.00033179802541528973
# best score: 174.000000
# Overlap:125490
# Error:0.000277296631274982
# best score: 170.000000
# Overlap:129295
# Error:0.0003340663746872643
# best score: 170.000000
# Overlap:125631
# Error:0.0002744888792257793
# best score: 143.000000
# Overlap:128816
# Error:0.00033562978886344895
# best score: 187.000000
# Overlap:126207
# Error:0.00027064279410473615
# best score: 150.000000
# Overlap:129079
# Error:0.00033199108225914157
# best score: 176.000000
# Overlap:127601
# Error:0.00027015587071762626
# best score: 163.000000
# Overlap:129556
# Error:0.0003318847129191604
# best score: 179.000000
# Overlap:127811
# Error:0.0002668790461208768
# best score: 144.000000
# Overlap:130022
# Error:0.00032861068219859374
# best score: 168.000000
# Overlap:128871
# Error:0.0002672465049766346
# best score: 170.000000
# Overlap:130298
# Error:0.0003296040907124073
# best score: 158.000000
# Overlap:128472
# Error:0.00027023334905897263
# best score: 178.000000
# Overlap:130881
# Error:0.0003275527573237886
# best score: 184.000000
# Overlap:129919
# Error:0.0002712580257457287
# best score: 170.000000
# Overlap:130871
# Error:0.000326680210557818
# best score: 169.000000
# Overlap:130204
# Error:0.000265688368209528
# best score: 162.000000
# Overlap:131952
# Error:0.00032614620070389245
# best score: 173.000000
# Overlap:131112
# Error:0.00026479760345855715
# best score: 170.000000
# Overlap:133211
# Error:0.0003200153017186761
# best score: 173.000000
# Overlap:131948
# Error:0.00026019353260216645
# best score: 170.000000
# Overlap:134001
# Error:0.0003232367789294179
# best score: 176.000000
# Overlap:133265
# Error:0.00026322617259891745
# best score: 172.000000
# Overlap:133819
# Error:0.0003211727380797053
# best score: 177.000000
# Overlap:133014
# Error:0.00026916040728766264
# best score: 171.000000
# Overlap:134071
# Error:0.00031898281711471453
# best score: 178.000000
# Overlap:133370
# Error:0.000267049568953502
# best score: 158.000000
# Overlap:134860
# Error:0.000318922824391464
# best score: 183.000000
# Overlap:134051
# Error:0.00026573345729199885
# best score: 164.000000
# Overlap:134910
# Error:0.0003180258688484541
# best score: 177.000000
# Overlap:134135
# Error:0.0002621099071494816
# best score: 174.000000
# Overlap:134907
# Error:0.00031536418269322285
# best score: 195.000000
# Overlap:135018
# Error:0.000265055586951668
# best score: 168.000000
# Overlap:134587
# Error:0.0003147555475957473
# best score: 164.000000
# Overlap:135936
# Error:0.00027200163516336034
# best score: 175.000000
# Overlap:135251
# Error:0.000312055421068877
# best score: 183.000000
# Overlap:135257
# Error:0.000263582468555201
# best score: 171.000000
# Overlap:135801
# Error:0.00031081172916138327
# best score: 209.000000
# Overlap:135321
# Error:0.000261275695270653
# best score: 197.000000
# Overlap:135669
# Error:0.0003066745953617973
# best score: 207.000000
# Overlap:135289
# Error:0.0002621082720608379
# best score: 164.000000
# Overlap:135460
# Error:0.00030564411314110417
# best score: 211.000000
# Overlap:134201
# Error:0.00026216638659959124
# best score: 175.000000
# Overlap:136278
# Error:0.000302532264663151
# best score: 195.000000
# Overlap:136128
# Error:0.0002638980347288719
# best score: 203.000000
# Overlap:136647
# Error:0.0003009681990478721
# best score: 183.000000
# Overlap:135533
# Error:0.0002633422832275981
# best score: 191.000000
# Overlap:136757
# Error:0.00029689185829118875
# best score: 189.000000
# Overlap:135755
# Error:0.00026203825323056025
# best score: 168.000000
# Overlap:136824
# Error:0.00030120870413834477
# best score: 191.000000
# Overlap:134974
# Error:0.0002625741880590096
# best score: 174.000000
# Overlap:136909
# Error:0.0002966578596126021
# best score: 200.000000
# Overlap:134203
# Error:0.0002657106025042786
# best score: 195.000000
# Overlap:136846
# Error:0.00029258378924095944
# best score: 206.000000
# Overlap:136575
# Error:0.00026219533059889234
# best score: 188.000000
# Overlap:137856
# Error:0.0002916941911263789
# best score: 197.000000
# Overlap:133965
# Error:0.00026694414112173585
# best score: 205.000000
# Overlap:138778
# Error:0.0002862237511079134
# best score: 229.000000
# Overlap:137120
# Error:0.0002636515018554512
# best score: 184.000000
# Overlap:139271
# Error:0.000285291566125942
# best score: 214.000000
# Overlap:136770
# Error:0.00026167993031610937
# best score: 186.000000
# Overlap:139434
# Error:0.0002827980275721703
# best score: 210.000000
# Overlap:135872
# Error:0.00026198376107451144
# best score: 189.000000
# Overlap:139618
# Error:0.000284252713682211
# best score: 182.000000
# Overlap:134065
# Error:0.0002651096719747912
# best score: 198.000000
# Overlap:140552
# Error:0.0002792683624024507
# best score: 197.000000
# Overlap:132558
# Error:0.0002666494063176278
# best score: 213.000000
# Overlap:141103
# Error:0.0002735125455920519
# best score: 195.000000
# Overlap:133825
# Error:0.00026400344615747903
# best score: 206.000000
# Overlap:140566
# Error:0.00027470393335126417
# best score: 206.000000
# Overlap:134471
# Error:0.0002648749428421236
# best score: 197.000000
# Overlap:140006
# Error:0.00027517958180944076
# best score: 202.000000
# Overlap:135915
# Error:0.00026386393859302197
# best score: 196.000000
# Overlap:140134
# Error:0.0002725193764703238
# best score: 196.000000
# Overlap:135825
# Error:0.00026347895517727694
# best score: 194.000000
# Overlap:139995
# Error:0.00027275084105147834
# best score: 203.000000
# Overlap:137356
# Error:0.0002649516610584025
# best score: 185.000000
# Overlap:140298
# Error:0.00027259658154329833
# best score: 239.000000
# Overlap:138048
# Error:0.00026350289778613524
# best score: 187.000000
# Overlap:140531
# Error:0.0002697144043074996
# best score: 198.000000
# Overlap:140593
# Error:0.0002659403792542167
# best score: 181.000000
# Overlap:140527
# Error:0.0002673391403265503
# best score: 190.000000
# Overlap:140641
# Error:0.00026804247925543993
# best score: 168.000000
# Overlap:140667
# Error:0.0002700004182084181
# best score: 218.000000
# Overlap:141742
# Error:0.0002662578184920511
# Overlap:141138
# Error:0.0002616870243115238
# best score: 189.000000
# Overlap:143349
# Error:0.0002688500196931242
# best score: 237.000000
# Overlap:142226
# Error:0.00025861511444229154
# best score: 187.000000
# Overlap:144797
# Error:0.00026888685777713684
# best score: 218.000000
# Overlap:142652
# Error:0.0002581240623504784
# best score: 199.000000
# Overlap:146085
# Error:0.00026717291842395823
# best score: 221.000000
# Overlap:142378
# Error:0.00026067343420378534
# best score: 170.000000
# Overlap:147324
# Error:0.0002684477913874243
# best score: 228.000000
# Overlap:144227
# Error:0.00025812824276572223
# best score: 207.000000
# Overlap:147245
# Error:0.0002671097435375483
# best score: 222.000000
# Overlap:144598
# Error:0.00025692560283527315
# best score: 194.000000
# Overlap:146364
# Error:0.00027028065014658383
# best score: 193.000000
# Overlap:145053
# Error:0.00025734605679221897
# best score: 188.000000
# Overlap:148094
# Error:0.00027032712980143284
# best score: 206.000000
# Overlap:145262
# Error:0.00025679577908045047
# best score: 197.000000
# Overlap:147622
# Error:0.00027314621522552267
# best score: 221.000000
# Overlap:145818
# Error:0.00025543765550219524
# best score: 202.000000
# Overlap:148261
# Error:0.0002732682676065331
# best score: 206.000000
# Overlap:146427
# Error:0.0002544700374802598
# best score: 216.000000
# Overlap:149350
# Error:0.00027406992592561065
# best score: 220.000000
# Overlap:146755
# Error:0.00025284325624307693
# best score: 204.000000
# Overlap:150792
# Error:0.00027610212161031147
# best score: 223.000000
# Overlap:145970
# Error:0.000253482265615367
# best score: 218.000000
# Overlap:150165
# Error:0.0002729701302256876
# best score: 224.000000
# Overlap:145639
# Error:0.00025370639512081294
# best score: 216.000000
# Overlap:150015
# Error:0.00027514922424437137
# best score: 252.000000
# Overlap:145870
# Error:0.00025300620958250533
# best score: 236.000000
# Overlap:150360
# Error:0.00027630473539270474
# best score: 230.000000
# Overlap:146334
# Error:0.00025471287110343573
# best score: 209.000000
# Overlap:150741
# Error:0.0002757761669498443
# best score: 224.000000
# Overlap:146472
# Error:0.000255179583427019
# best score: 194.000000
# Overlap:150142
# Error:0.000277754166771768
# best score: 204.000000
# Overlap:146806
# Error:0.0002546361404913587
# best score: 225.000000
# Overlap:151387
# Error:0.0002748375120413326
# best score: 217.000000
# Overlap:147234
# Error:0.00025679051833027075
# best score: 192.000000
# Overlap:150595
# Error:0.0002735940834447266
# best score: 206.000000
# Overlap:147009
# Error:0.00025788429427206293
# best score: 236.000000
# Overlap:152019
# Error:0.00027009679750905543
# best score: 221.000000
# Overlap:146750
# Error:0.00025388364106660203
# best score: 223.000000
# Overlap:152209
# Error:0.00027217006225506744
# best score: 200.000000
# Overlap:147360
# Error:0.0002568610926571478
# best score: 242.000000
# Overlap:152958
# Error:0.00027108990957298195
# best score: 203.000000
# Overlap:147836
# Error:0.000255293044098356
# best score: 252.000000
# Overlap:153519
# Error:0.000269377706866088
# best score: 209.000000
# Overlap:147933
# Error:0.00025942933551837706
# best score: 232.000000
# Overlap:153397
# Error:0.0002694015192641936
# best score: 214.000000
# Overlap:148145
# Error:0.0002548339253760789
# best score: 241.000000
# Overlap:153395
# Error:0.0002727005641762517
# best score: 222.000000
# Overlap:149193
# Error:0.00025771716431177884
# best score: 199.000000
# Overlap:153833
# Error:0.00027089743696176704
# best score: 229.000000
# Overlap:148795
# Error:0.0002585042670023476
# best score: 207.000000
# Overlap:153690
# Error:0.00026959498402347984
# best score: 212.000000
# Overlap:149225
# Error:0.00025944500265850354
# best score: 218.000000
# Overlap:154495
# Error:0.00027053426362028197
# best score: 232.000000
# Overlap:148804
# Error:0.0002596694499315694
# best score: 242.000000
# Overlap:155275
# Error:0.0002653821162897963
# best score: 277.000000
# Overlap:149253
# Error:0.00025935275608655184
# best score: 267.000000
# Overlap:155955
# Error:0.00026471314263345016
# best score: 218.000000
# Overlap:150155
# Error:0.00026221206734507516
# best score: 258.000000
# Overlap:156199
# Error:0.0002620989846087437
# best score: 226.000000
# Overlap:150151
# Error:0.0002608342340644821
# best score: 217.000000
# Overlap:155891
# Error:0.0002622140694107988
# best score: 254.000000
# Overlap:149882
# Error:0.0002594172177400148
# best score: 222.000000
# Overlap:157272
# Error:0.00026148593996376274
# best score: 235.000000
# Overlap:149700
# Error:0.00026065951631646885
# best score: 226.000000
# Overlap:157936
# Error:0.00026140612075039807
# best score: 213.000000
# Overlap:150797
# Error:0.000259198596720572
# best score: 226.000000
# Overlap:158331
# Error:0.00026363758043701263
# best score: 245.000000
# Overlap:151600
# Error:0.00026254721281188315
# best score: 234.000000
# Overlap:158644
# Error:0.0002610921941444827
# best score: 267.000000
# Overlap:152287
# Error:0.00025873749852782177
# best score: 269.000000
# Overlap:159478
# Error:0.0002614988870929828
# best score: 243.000000
# Overlap:152301
# Error:0.00026082191454175694
# best score: 235.000000
# Overlap:159317
# Error:0.00025950549002499626
# best score: 249.000000
# Overlap:151696
# Error:0.0002616803754295119
# best score: 235.000000
# Overlap:160800
# Error:0.0002594936798911112
# best score: 242.000000
# Overlap:152400
# Error:0.00026482936189963153
# best score: 249.000000
# Overlap:161271
# Error:0.00025746730286099984
# best score: 246.000000
# Overlap:152742
# Error:0.0002660402473363666
# best score: 259.000000
# Overlap:161789
# Error:0.00025600881365499224
# best score: 224.000000
# Overlap:152865
# Error:0.00026629156316710246
# best score: 305.000000
# Overlap:162178
# Error:0.00025454937354255
# best score: 236.000000
# Overlap:153312
# Error:0.00026399153729470595
# best score: 282.000000
# Overlap:162097
# Error:0.00025615445528503035
# best score: 232.000000
# Overlap:153709
# Error:0.0002650529937979842
# best score: 303.000000
# Overlap:161881
# Error:0.00025234739304865866
# best score: 258.000000
# Overlap:153834
# Error:0.00026376363555444607
# best score: 277.000000
# Overlap:162393
# Error:0.0002478658461448101
# best score: 298.000000
# Overlap:154108
# Error:0.00026220015867264867
# best score: 246.000000
# Overlap:162533
# Error:0.0002511210206597539
# best score: 255.000000
# Overlap:154682
# Error:0.0002622171338383423
# best score: 236.000000
# Overlap:162358
# Error:0.0002444382290034473
# best score: 233.000000
# Overlap:155073
# Error:0.0002588710031936744
# best score: 243.000000
# Overlap:163085
# Error:0.00024301456000806954
# best score: 236.000000
# Overlap:156387
# Error:0.0002567493369315834
# best score: 237.000000
# Overlap:163126
# Error:0.00024129074407171954
# best score: 247.000000
# Overlap:156456
# Error:0.00025299717289042705
# best score: 267.000000
# Overlap:163925
# Error:0.00023882010361807817
# best score: 264.000000
# Overlap:157010
# Error:0.00025426034201870743
# best score: 272.000000
# Overlap:163858
# Error:0.0002355242339309361
# best score: 272.000000
# Overlap:157061
# Error:0.000248809839019602
# best score: 261.000000
# Overlap:163883
# Error:0.00023573911886837754
# best score: 275.000000
# Overlap:157620
# Error:0.0002480078088112736
# best score: 255.000000
# Overlap:164655
# Error:0.00023505077639175202
# best score: 296.000000
# Overlap:158511
# Error:0.00024573900797425285
# best score: 255.000000
# Overlap:163603
# Error:0.00023508008201404741
# best score: 282.000000
# Overlap:158654
# Error:0.00024696572923492476
# best score: 261.000000
# Overlap:163470
# Error:0.00023020255617768517
# best score: 262.000000
# Overlap:158931
# Error:0.00024406669773846009
# best score: 222.000000
# Overlap:163516
# Error:0.00023206680488864007
# best score: 251.000000
# Overlap:159055
# Error:0.0002447432283091815
# best score: 265.000000
# Overlap:164278
# Error:0.00023102645110568694
# best score: 284.000000
# Overlap:160032
# Error:0.0002395607845332154
# best score: 276.000000
# Overlap:164884
# Error:0.0002265501863226268
# best score: 301.000000
# Overlap:161161
# Error:0.00023801202570798436
# best score: 222.000000
# Overlap:165851
# Error:0.00022382349206519195
# best score: 296.000000
# Overlap:161151
# Error:0.00023424283533539218
# best score: 254.000000
# Overlap:166658
# Error:0.00022097434232073556
# best score: 316.000000
# Overlap:161286
# Error:0.00023273225691231684
# best score: 292.000000
# Overlap:167319
# Error:0.00021564403148394167
# best score: 287.000000
# Overlap:161210
# Error:0.00022630714299457533
# best score: 286.000000
# Overlap:168208
# Error:0.00021388130977689413
# best score: 324.000000
# Overlap:161241
# Error:0.0002228276460994015
# best score: 266.000000
# Overlap:167826
# Error:0.00020885240247346142
# best score: 344.000000
# Overlap:162279
# Error:0.0002196072718910625
# best score: 281.000000
# Overlap:166868
# Error:0.00020877468076256189
# best score: 349.000000
# Overlap:162480
# Error:0.00021979323160027124
# best score: 283.000000
# Overlap:167945
# Error:0.00020618026715912187
# best score: 318.000000
# Overlap:162682
# Error:0.00020897663425901818
# best score: 290.000000
# Overlap:168261
# Error:0.00020468128791364118
# best score: 358.000000
# Overlap:162821
# Error:0.00020540228130897016
# best score: 311.000000
# Overlap:168487
# Error:0.00019944635942469326
# best score: 328.000000
# Overlap:164275
# Error:0.00020450239083377042
# best score: 305.000000
# Overlap:167920
# Error:0.0001977144464772571
# best score: 298.000000
# Overlap:165078
# Error:0.00020134014848938544
# best score: 292.000000
# Overlap:167431
# Error:0.00019759028302831358
# best score: 309.000000
# Overlap:166109
# Error:0.00019687371941763538
# best score: 322.000000
# Overlap:166306
# Error:0.00019252284103156596
# best score: 308.000000
# Overlap:165712
# Error:0.0001867254146082943
# best score: 275.000000
# Overlap:166700
# Error:0.0001924064955055479
# best score: 352.000000
# Overlap:166404
# Error:0.00018211442163864897
# best score: 291.000000
# Overlap:165973
# Error:0.00018093646547796488
# best score: 350.000000
# Overlap:167622
# Error:0.00017150076080278023
# best score: 349.000000
# Overlap:167275
# Error:0.00016822922925165915
# best score: 424.000000
# Overlap:167283
# Error:0.00015181222752667616
# best score: 328.000000
# Overlap:168592
# Error:0.00015129995019502404
# best score: 435.000000
# Overlap:167852
# Error:0.00013525367274275173
# best score: 355.000000
# Overlap:168948
# Error:0.00013302162423233193
# best score: 564.000000
# Overlap:168227
# Error:0.0001090918322236983
# best score: 417.000000
# Overlap:169438
# Error:0.00011677157543656801
# Overlap:169855
# Error:0.0

# %%
utils.imageFolder2mpeg('aligned_frames', fps=30)

# %% [markdown]
# ### Part 4: Create background panorama
#
# In this part you will remove moving objects from the video and create a background panorama that should incorporate pixels from all the frames.
#
# In the video you produced in __part 3__ each pixel appears in several frames. You need to estimate which of the many colors correspond to the background. We take advantage of the fact that the background color is fixed while the foreground color changes frequently (because foreground moves).
#
# <img src="images/project_5/background.jpg" alt="Drawing" style="float: center; width: 500px"/>
#
#
# For each pixel in the sequence of __part 3__, determine all valid colors (colors that come from all frames that overlap that pixel). You can experiment with different methods for determining the background color of each pixel, as discussed in class. Perform the same procedure for all pixels and generate output. The output should be a completed panorama showing only pixels of background or non-moving objects.

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import statistics
import pdb

# for each pixel, find the median across the 900 frames
# vectorized approach
ht, wd = projected[0].shape[0], projected[0].shape[1]
median_calc = np.zeros((ht,wd,3,len(projected)))
median_calc.fill(np.nan)

frame,x,y,c = np.nonzero(projected)
median_calc[x,y,c,frame] = projected[frame,x,y,c]
median = np.nanmedian(median_calc,axis=3)

plt.figure(figsize=(60,10))
plt.imshow(median*255)

# %% [markdown]
# ### Part 5: Create background movie
#
# Map the background panorama to the movie coordinates. For each frame of the movie, say frame 1, you need to estimate a projection from the panorama to frame 1. Note, you should be able to re-use the homographies that you estimated in __Part 3__. Perform this for all frames and generate a movie that looks like the input movie but shows only background pixels. All moving objects that belong to the foreground must be removed.

# %%
import os
import cv2
import numpy as np

#Go through all past homographies

for i in range(0, 2)
    cur_H = pastHomographies[i][450]
    print(cur_H.shape)
    inv_H = np.linalg.inv(cur_H)
    img_warped = cv2.warpPerspective(median, inv_H, (360, 480))

# %%
utils.imageFolder2mpeg('part5_frames', fps=30)

# %% [markdown]
# ### Part 6: Create foreground movie
#
# In the background video, moving objects are removed. In each frame, those pixels that are different enough than the background color are considered foreground. For each frame determine foreground pixels and generate a movie that only includes foreground pixels.

# %%
import os
import cv2
import numpy as np

for i in range(0, 900):
    difference = frames[i] - (warped_imgs[i]/255)
    cv2.imwrite('part6_frames/a{:04d}.jpg'.format(i), difference*255)

# %%
utils.imageFolder2mpeg('part6_frames', fps=30)

# %% [markdown]
# ## Bells and whistles
